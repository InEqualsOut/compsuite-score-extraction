# %% [markdown]
# # Import Source Code and Enter URL
#
# Enter direct URL from CompetitionSuite for the program to read the score tables. There may be more than one table on each page, and the below comments will help with selecting the correct parameters.

# %%
from src.web_scraper import scores_and_ranks

url = 'https://recaps.competitionsuite.com/c911ac2b-621c-470a-83be-07ee214c3ca5.htm'

dfs = scores_and_ranks(url)

# %%
## How many recaps are on the page? If there is more than one, you will need to select one in the next cell.

## View the tables
for i, df in enumerate(dfs, start=1):
    print(f"\nTABLE {i}")
    print(df.head())

print(f"There are a total of {i} tables.")
# Out:
# TABLE 1
#             group         location  score_1  rank_1  score_2  rank_2  score_3  \
# 0                                       NaN     NaN      NaN     NaN      NaN
# 1      J. Kennedy        C. Walker      NaN     NaN      NaN     NaN      NaN
# 2             Ovr              Mus      NaN     NaN      NaN     NaN      NaN
# 3     Sherwood HS     Sherwood, OR    100.0     1.0    100.0     1.0   30.000
# 4  Clear Brook HS  Friendswood, TX     99.5     2.0     99.0     3.0   29.775
#
#    rank_3  score_4  rank_4  ...  score_27  rank_27  score_28  rank_28  \
# 0     NaN      NaN     NaN  ...       NaN      NaN       NaN      NaN
# 1     NaN      NaN     NaN  ...       NaN      NaN       NaN      NaN
# 2     NaN      NaN     NaN  ...       NaN      NaN       NaN      NaN
# 3     1.0     96.0     1.0  ...      19.8      1.0     19.45      2.0
# 4     2.0     94.0     5.0  ...      19.2      4.0     19.35      3.0
#
#    score_29  rank_29  score_30  rank_30  score_31  rank_31
# 0       NaN      NaN       NaN      NaN       NaN      NaN
# 1       NaN      NaN       NaN      NaN       NaN      NaN
# 2       NaN      NaN       NaN      NaN       NaN      NaN
# 3    97.125      1.0       0.0      NaN    97.125      1.0
# 4    96.400      2.0       0.0      NaN    96.400      2.0
#
# [5 rows x 64 columns]
#
# TABLE 2
#                  group       location  score_1  rank_1  score_2  rank_2  \
# 0                                          NaN     NaN      NaN     NaN
# 1        E. Argenziano        B. Kuhn      NaN     NaN      NaN     NaN
# 2                  Ovr            Mus      NaN     NaN      NaN     NaN
# 3           Infinity 2    Orlando, FL    100.0     1.0     99.0     1.0
# 4  Civitas Independent  Rock Hill, SC     96.0     2.0     97.0     3.0
#
#    score_3  rank_3  score_4  rank_4  ...  score_27  rank_27  score_28  \
# 0      NaN     NaN      NaN     NaN  ...       NaN      NaN       NaN
# 1      NaN     NaN      NaN     NaN  ...       NaN      NaN       NaN
# 2      NaN     NaN      NaN     NaN  ...       NaN      NaN       NaN
# 3    29.85     1.0     99.0     1.0  ...     19.20      2.0      19.3
# 4    28.95     2.0     98.0     2.0  ...     18.75      4.0      18.8
#
#    rank_28  score_29  rank_29  score_30  rank_30  score_31  rank_31
# 0      NaN       NaN      NaN       NaN      NaN       NaN      NaN
# 1      NaN       NaN      NaN       NaN      NaN       NaN      NaN
# 2      NaN       NaN      NaN       NaN      NaN       NaN      NaN
# 3      2.0    97.500      1.0       0.0      NaN    97.500      1.0
# 4      4.0    96.275      2.0       0.0      NaN    96.275      2.0
#
# [5 rows x 64 columns]
#
# TABLE 3
#             group         location  score_1  rank_1  score_2  rank_2  score_3  \
# 0                                       NaN     NaN      NaN     NaN      NaN
# 1       J. Davila      M. McIntosh      NaN     NaN      NaN     NaN      NaN
# 2             Ovr              Mus      NaN     NaN      NaN     NaN      NaN
# 3         Avon HS         Avon, IN    100.0     1.0    100.0     1.0   30.000
# 4  Chino Hills HS  Chino Hills, CA     98.0     3.0     98.5     2.0   29.475
#
#    rank_3  score_4  rank_4  ...  score_27  rank_27  score_28  rank_28  \
# 0     NaN      NaN     NaN  ...       NaN      NaN       NaN      NaN
# 1     NaN      NaN     NaN  ...       NaN      NaN       NaN      NaN
# 2     NaN      NaN     NaN  ...       NaN      NaN       NaN      NaN
# 3     1.0     99.5     1.0  ...     19.70      1.0    19.650      1.0
# 4     2.0     97.5     2.0  ...     19.45      2.0    19.375      2.0
#
#    score_29  rank_29  score_30  rank_30  score_31  rank_31
# 0       NaN      NaN       NaN      NaN       NaN      NaN
# 1       NaN      NaN       NaN      NaN       NaN      NaN
# 2       NaN      NaN       NaN      NaN       NaN      NaN
# 3    98.600      1.0       0.0      NaN    98.600      1.0
# 4    97.775      2.0       0.0      NaN    97.775      2.0
#
# [5 rows x 64 columns]
#
# TABLE 4
#               group         location  score_1  rank_1  score_2  rank_2  \
# 0                                         NaN     NaN      NaN     NaN
# 1          C. Heiny         S. Koter      NaN     NaN      NaN     NaN
# 2               Ovr              Mus      NaN     NaN      NaN     NaN
# 3  Pulse Percussion  Westminster, CA     99.0     2.0     98.5     2.0
# 4          Rhythm X       Dayton, OH    100.0     1.0     98.0     3.0
#
#    score_3  rank_3  score_4  rank_4  ...  score_27  rank_27  score_28  \
# 0      NaN     NaN      NaN     NaN  ...       NaN      NaN       NaN
# 1      NaN     NaN      NaN     NaN  ...       NaN      NaN       NaN
# 2      NaN     NaN      NaN     NaN  ...       NaN      NaN       NaN
# 3   29.625     3.0     98.5     2.0  ...     19.80      1.0    19.800
# 4   29.700     2.0    100.0     1.0  ...     19.45      2.0    19.425
#
#    rank_28  score_29  rank_29  score_30  rank_30  score_31  rank_31
# 0      NaN       NaN      NaN       NaN      NaN       NaN      NaN
# 1      NaN       NaN      NaN       NaN      NaN       NaN      NaN
# 2      NaN       NaN      NaN       NaN      NaN       NaN      NaN
# 3      1.0    98.925      1.0       0.0      NaN    98.925      1.0
# 4      2.0    98.075      2.0       0.0      NaN    98.075      2.0
#
# [5 rows x 64 columns]
# There are a total of 4 tables.

# %% [markdown]
# # Preview the Table

# %%
which_table = 2                                   ## Select the desired table

df=dfs[which_table]    

df1=df.drop(labels=[0,1,2])                       ## This will remove the first three rows with the blanks and judge name
df1
# Out:
#                   group          location  score_1  rank_1  score_2  rank_2  \
# 3               Avon HS          Avon, IN    100.0     1.0    100.0     1.0
# 4        Chino Hills HS   Chino Hills, CA     98.0     3.0     98.5     2.0
# 5          Dartmouth HS     Dartmouth, MA     98.5     2.0     97.5     4.0
# 6            Arcadia HS       Arcadia, CA     97.0     5.0     98.0     3.0
# 7              Ayala HS   Chino Hills, CA     97.5     4.0     96.0     5.0
# 8          Cupertino HS     Cupertino, CA     94.5     7.0     95.0     6.0
# 9       Broken Arrow HS  Broken Arrow, OK     95.0     6.0     94.0     7.0
# 10           Lambert HS       Suwanee, GA     94.0     8.0     92.0     9.0
# 11          Sparkman HS       Harvest, AL     93.5     9.0     93.0     8.0
# 12         Homestead HS     Cupertino, CA     93.0    10.0     89.0    11.0
# 13            Milton HS        Milton, GA     92.0    11.0     91.0    10.0
# 14      Center Grove HS     Greenwood, IN     91.0    12.0     87.0    14.0
# 15  Franklin Central HS  Indianapolis, IN     90.0    13.0     87.5    13.0
# 16       Centerville HS   Centerville, OH     87.0    15.0     88.0    12.0
# 17             Petal HS         Petal, MS     88.0    14.0     86.0    15.0
#
#     score_3  rank_3  score_4  rank_4  ...  score_27  rank_27  score_28  \
# 3    30.000     1.0     99.5     1.0  ...     19.70      1.0    19.650
# 4    29.475     2.0     97.5     2.0  ...     19.45      2.0    19.375
# 5    29.400     3.0     97.0     3.0  ...     19.30      3.0    19.350
# 6    29.250     4.0     96.0     4.0  ...     18.80      5.0    19.000
# 7    29.025     5.0     95.0     5.0  ...     18.90      4.0    18.950
# 8    28.425     6.0     93.0     6.0  ...     18.20      7.0    18.500
# 9    28.350     7.0     92.0     7.0  ...     18.50      6.0    18.500
# 10   27.900     9.0     91.0     9.0  ...     18.05      8.0    17.925
# 11   27.975     8.0     91.5     8.0  ...     17.80      9.0    18.050
# 12   27.300    11.0     90.5    10.0  ...     17.40     10.0    17.725
# 13   27.450    10.0     89.5    12.0  ...     16.90     12.0    17.000
# 14   26.700    12.0     88.5    14.0  ...     17.20     11.0    17.575
# 15   26.625    13.0     90.0    11.0  ...     16.70     14.0    17.350
# 16   26.250    14.0     88.0    15.0  ...     16.50     15.0    16.900
# 17   26.100    15.0     89.0    13.0  ...     16.80     13.0    17.225
#
#     rank_28  score_29  rank_29  score_30  rank_30  score_31  rank_31
# 3       1.0    98.600      1.0       0.0      NaN    98.600      1.0
# 4       2.0    97.775      2.0       0.0      NaN    97.775      2.0
# 5       3.0    97.525      3.0       0.0      NaN    97.525      3.0
# 6       4.0    95.900      4.0       0.0      NaN    95.900      4.0
# 7       5.0    93.438      5.0       0.0      NaN    93.438      5.0
# 8       6.0    92.988      6.0       0.0      NaN    92.988      6.0
# 9       6.0    92.188      7.0       0.0      NaN    92.188      7.0
# 10      9.0    91.225      9.0       0.0      NaN    91.225      8.0
# 11      8.0    91.338      8.0       0.4      NaN    90.938      9.0
# 12     10.0    88.588     11.0       0.0      NaN    88.588     10.0
# 13     14.0    88.538     12.0       0.0      NaN    88.538     11.0
# 14     11.0    88.625     10.0       0.2      NaN    88.425     12.0
# 15     12.0    88.413     13.0       0.0      NaN    88.413     13.0
# 16     15.0    87.150     14.0       0.0      NaN    87.150     14.0
# 17     13.0    86.425     15.0       0.0      NaN    86.425     15.0
#
# [15 rows x 64 columns]

# %%
filename = '2022-psw-finals.csv'              ## Write appropriate file name
df1.to_csv(f"files/{filename}", index=False)
